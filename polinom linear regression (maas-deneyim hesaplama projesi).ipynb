# %%
# polinom çok terimli fonksiyonlardır.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures

# %%
df= pd.read_csv("polynomial.csv",sep=";")

# %%
df
# Out:
#    deneyim    maas
# 0        1    4500
# 1        2    5000
# 2        3    6000
# 3        4    8000
# 4        5   11000
# 5        6   15000
# 6        7   20000
# 7        8   30000
# 8        9   50000
# 9       10  100000

# %%
polynomial_regression=PolynomialFeatures(degree=8)

# %%
plt.scatter(df["deneyim"],df["maas"])
plt.xlabel("deneyim(yıl)")
plt.ylabel("maas")
plt.savefig("1.png",dpi=300)
plt.show()

# %%
# görüldüğü gibi doğrusal dağılmıyor veri seti linear regression uygulanırsa uygun sonuçlar çıkmayacaktır.

# %%
reg=LinearRegression()
reg.fit(df[["deneyim"]],df["maas"])
plt.xlabel("Deneyim (yıl)")
plt.ylabel("maas")
plt.scatter(df["deneyim"],df["maas"])
xekseni= df["deneyim"]
yekseni=reg.predict(df[["deneyim"]])
plt.plot(xekseni,yekseni,color="green",label="Linear regression" )
plt.legend()
plt.show()

# %%
# belirttiğimiz gibi çok kötü bir doğru bura da tahminler hiç sağlıklı yapılamayacaktır.
# bu veri setine polinom regression uygulamaya karar verdik.

# %%
polynomial_regression=PolynomialFeatures(degree=8)
x_polynomial=polynomial_regression.fit_transform(df[["deneyim"]])

# %%
reg=LinearRegression()
reg.fit(x_polynomial,df["maas"])
# Out:
# LinearRegression()

# %%
# yukarıda ki komutta yapay zekayı eğitme işlemi yapıyoruz.

# %%
# şimdi eldeki verilerimize göre modelimiz nasıl bir sonuç grafiği oluşturuyor onu görelim

# %%
y_head=reg.predict(x_polynomial)
plt.plot(df["deneyim"],y_head,color="red",label="polynomial regression")
plt.legend()
plt.scatter(df["deneyim"],df["maas"])
plt.show()

# %%
x_polynomial1=polynomial_regression.fit_transform([[100]])
reg.predict(x_polynomial1)
# Out:
# array([1.56446055e+15])

# %%
# ddeneyim yılını vererek alması gereken maası tahmin ettirdik.
